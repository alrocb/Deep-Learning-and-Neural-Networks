# %% [markdown]
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/dkaratzas/DL2022-23/blob/main/Problems%206%20-%20Pretrained%20CNNs/P6_CNN_PretrainedModels.ipynb)

# %% [markdown]
# # CNN Transfer Learning

# %% [markdown]
# In this notebook we will learn how to finetune a modern
# CNN architecture from the [`torchvision models`](https://pytorch.org/docs/stable/torchvision/models.html), which has been pretrained on the [Imagenet dataset](http://www.image-net.org/). The [`torchvision models`](https://pytorch.org/docs/stable/torchvision/models.html) module implements lots of popular CNN models such as: AlexNet, VGG, ResNet, DenseNet, GoogLeNet, etc.
#
#
# *Credit: This notebook has been adapted from the official [PyTorch finetuning tutorial](https://pytorch.org/tutorials/beginner/finetuning_torchvision_models_tutorial.html).*
#
# The Imagenet dataset has 1000 classes and millions of images. Training a ResNet-50 model on ImageNet-1k with a single GPU takes several days. The key idea of transfer learning is to reuse the knowledge learned in one task to solve a different task. Transfer learning is specially useful when we do not have lots of training data for the new task nad/or when we want to speed up the training of the new model.
#
# For the target task we will use the [hymenoptera_data dataset](https://download.pytorch.org/tutorial/hymenoptera_data.zip), which consists in only **two classes** ('ants' and 'bees') and only around **one hundred training examples** for each class.

# %% [markdown]
# <table>
#     <tr>
#         <td style="text-align:center">bee</td><td style="text-align:center">ant</td>
#     </tr>
#     <tr>
#         <td><img src="......"></td>
#         <td><img src="......"></td>
#     </tr>
# </table>

# %% [markdown]
# We will perform two types of transfer learning: finetuning and feature extraction. In **finetuning**, we start with a pretrained model and update *all* of the model’s parameters for a new task. In **feature extraction**,
# we start with a pretrained model and only update the final layer weights.
#
# In general both transfer learning methods follow the same few steps:
#
# -  Initialize the pretrained model
# -  Reshape the final layer(s) to have the same number of outputs as the number of classes in the new dataset
# -  Define for the optimization algorithm which parameters we want to update during training
# -  Run the training step

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Load the necessary libraries
#
# The following code imports the packages needed for this example.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import torchvision
from torchvision import datasets, models, transforms

import matplotlib.pyplot as plt
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  2.0.0+cu118
# Torchvision Version:  0.15.1+cu118

# %%
# If this cell fails you need to change the runtime of your colab notebook to GPU
# Go to Runtime -> Change Runtime Type and select GPU
assert torch.cuda.is_available(), "GPU is not enabled"

# use gpu if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Prepare the dataset
#
# The *hymenoptera_data* dataset is structured such that we can use the [`ImageFolder()`](https://pytorch.org/docs/stable/torchvision/datasets.html#torchvision.datasets.ImageFolder) dataset class. Below you can see how to use PyTorch to download a dataset archive, unzip it, and then use the `ImageFolder()` function to create subsets from each subfolder.
#
# Since we will be reusing a pretrained model we must initialize the data transforms as in the original model. See [here](https://pytorch.org/vision/0.8/models.html) for more details.

# %%
# download the dataset
url = 'https://download.pytorch.org/tutorial/hymenoptera_data.zip'
datasets.utils.download_and_extract_archive(url, './data')

data_dir = "./data/hymenoptera_data/"

# ResNet input size
input_size = (224,224)

# Just normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")


# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

print("Done")
# Out:
# Downloading https://download.pytorch.org/tutorial/hymenoptera_data.zip to ./data/hymenoptera_data.zip
# 100%|██████████| 47286322/47286322 [00:00<00:00, 171805272.76it/s]
# Extracting ./data/hymenoptera_data.zip to ./data
# Initializing Datasets and Dataloaders...
# Done
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# ### Visualize some images

# %%
import matplotlib.image as mpimg

# show some images
plt.figure(figsize=(16, 6))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    idx = np.random.randint(0,len(image_datasets['train'].samples))
    image = mpimg.imread(image_datasets['train'].samples[idx][0])
    plt.imshow(image)
    plt.axis('off');

# %% [markdown]
# Since we have very little training data it makes sense to use some data augmentation for training.
#
# <span style="color:blue">
#
# **Exercise 1**: Change the transforms in the code below in order to add some data augmentation to the training data. See if you can do a random crop instead of always cropping in the middle, and add horizontal flips. Then recreate the datasets and dataloaders.
#
# </span>

# %%
# CHANGE THE CODE BELOW

# ResNet input size
input_size = (224,224)

# Just normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")

# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

print("Done")
# Out:
# Initializing Datasets and Dataloaders...
# Done

# %% [markdown]
# ## Define the training function
#
# The `train_model` function handles the training and validation of a given model. As input, it takes a PyTorch model, a dictionary of dataloaders, a loss function, an optimizer, and a specified number of epochs to train and validate for.
#
# Instead of defining different functions for tranining and validation, we have combined everything into a single one below.
#
# Note that we also have implemented early stopping - we keep track of the performance of our model on the validation set, and we keep a copy of the best model found using Python's `copy.deepcopy()` function. After training finishes, we copy the best weights from the saved model.

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()

    acc_history = {"train": [], "val": []}
    losses = {"train": [], "val": []}

    # we will keep a copy of the best weights so far according to validation accuracy
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    losses[phase].append(loss.item())

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).cpu().numpy()

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            
            acc_history[phase].append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, acc_history, losses

# %% [markdown]
# ## Initialize the ResNet model
#
# We will use the Resnet18 model (the smaller one), as our dataset is small and only has two classes. When we print the model, we see that the last layer is a fully connected layer as shown below:
#
#
#    `(fc): Linear(in_features=512, out_features=1000, bias=True)`

# %%
# This is a function that we will adapt in various ways during the rest of the notebook, right now, it just creates and returns the model and the input size of images
def initialize_model():
    # Resnet18  
    model = models.resnet18()
    
    input_size = 224

    return model, input_size



# Initialize the model
model, input_size = initialize_model()

# Print the model we just instantiated
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 2**: Modify the function `initialize_model` so that it takes the number of classes `num_classes` as an argument, and it reinitializes `model.fc` to be a Linear layer with 512 input features and `num_classes` output features. Then use the function to create a model with 2 output classes.
#
# </span>

# %%
# This is a function that we will adapt in various ways during the rest of the notebook, right now, it just creates and returns the model and the input size of images
def initialize_model(num_classes):
    # Resnet18  
    model = models.resnet18()

    input_size = 224
    model.fc = nn.Linear(512 , num_classes)

    return model, input_size



# Initialize the model
model, input_size = initialize_model(2)

# Print the model we just instantiated
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# ### Run Training and Validation Step
#
# Let's start by training the model from scratch. What do you think will happen?

# %%
# Send the model to GPU
model = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 15

optimizer_ft = optim.Adam(model.parameters(), lr=0.001)

# Train and evaluate
model, hist, losses = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/14
# ----------
# train Loss: 0.9577 Acc: 0.5246
# val Loss: 2.0954 Acc: 0.5163
#
# Epoch 1/14
# ----------
# train Loss: 0.7183 Acc: 0.5738
# val Loss: 0.6688 Acc: 0.6601
#
# Epoch 2/14
# ----------
# train Loss: 0.6866 Acc: 0.5902
# val Loss: 0.7942 Acc: 0.6405
#
# Epoch 3/14
# ----------
# train Loss: 0.6700 Acc: 0.6189
# val Loss: 0.6865 Acc: 0.6209
#
# Epoch 4/14
# ----------
# train Loss: 0.6436 Acc: 0.6598
# val Loss: 0.8722 Acc: 0.6732
#
# Epoch 5/14
# ----------
# train Loss: 0.6380 Acc: 0.6393
# val Loss: 0.6781 Acc: 0.6275
#
# Epoch 6/14
# ----------
# train Loss: 0.6423 Acc: 0.6107
# val Loss: 0.6991 Acc: 0.6340
#
# Epoch 7/14
# ----------
# train Loss: 0.6641 Acc: 0.6230
# val Loss: 0.6325 Acc: 0.6667
#
# Epoch 8/14
# ----------
# train Loss: 0.5951 Acc: 0.6639
# val Loss: 0.6304 Acc: 0.7059
#
# Epoch 9/14
# ----------
# train Loss: 0.6414 Acc: 0.6352
# val Loss: 0.8867 Acc: 0.5752
#
# Epoch 10/14
# ----------
# train Loss: 0.6292 Acc: 0.6639
# val Loss: 0.7731 Acc: 0.6797
#
# Epoch 11/14
# ----------
# train Loss: 0.6661 Acc: 0.6434
# val Loss: 0.6378 Acc: 0.7059
#
# Epoch 12/14
# ----------
# train Loss: 0.6507 Acc: 0.6516
# val Loss: 0.6945 Acc: 0.6471
#
# Epoch 13/14
# ----------
# train Loss: 0.6316 Acc: 0.6270
# val Loss: 0.5852 Acc: 0.6797
#
# Epoch 14/14
# ----------
# train Loss: 0.6226 Acc: 0.6434
# val Loss: 0.6825 Acc: 0.6275
#
# Training complete in 1m 9s
# Best val Acc: 0.705882

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses["train"], label="training loss")
ax1.plot(losses["val"], label="validation loss")
ax1.legend()

ax2.plot(hist["train"],label="training accuracy")
ax2.plot(hist["val"],label="val accuracy")
ax2.legend()

plt.show()

# %% [markdown]
# Training from scratch with only 100 examples per class does not allow the network to perform very well in this task. It reaches at most 70% accuracy, and the loss seems not to descrease anymore.

# %% [markdown]
# ## Preparing the model for finetuning and feature extraction
#
# In order to finetune a model or use it for feature extraction, we need to first load the pretrained weights, and then to freeze the part of the model we do not want to change.
#
# In order to load the pretrained weights for the ResNet model we must change a bit more the function `initialize model`. One one hand, we need to load the weights of the pre-trained ResNet model, trained on ImageNet.
#
# Moreover, depending on whether we want to do finetuning (update all parameters of the model) or if we want to do feature extraction (update only the last fully connected layer), we must specify which parameter to update.
#
# The following function sets the `.requires_grad` attribute of all the parameters in the model to False. This way we are freezing the model, since the parameters with `.requires_grad=False` will not be updated during training.

# %%
def freeze_model(model):
    for param in model.parameters():
        param.requires_grad = False

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 3**: Modify the function `initialize_model` so that it takes an extra argument called `finetuning`. If this function is True, then all parameters of the model should be able to update. If it is false, this would mean that we want to do feature extraction, and all parameters of the model should be frozen except the last fully connected layer.
#
# In addition, look up the documentation of [`models.resnet18()`](https://pytorch.org/vision/main/models/generated/torchvision.models.resnet18.html) and initialise the models with the `DEFAULT` weights.
#
# Then create again your model,
#
# </span>

# %%
# This is a function that we will adapt in various ways during the rest of the notebook, right now, it just creates and returns the model and the input size of images
def initialize_model(num_classes, finetuning = True):
    # Resnet18  
    model = models.resnet18(weights='DEFAULT')

    if (finetuning == False):
      freeze_model(model)


    input_size = 224
    model.fc = nn.Linear(512 , num_classes)
    return model, input_size
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 174MB/s]
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# ### Create the Optimizer
#
# The final step for finetuning and feature extracting is to create an optimizer that **only** updates the desired parameters. Recall that after loading the pretrained model, if `finetuning == False` (we want to do feature extraction instead) we manually set all of the parameters' `.requires_grad` attributes to False. But the parameters of the reinitialized layer that we add afterwards have `.requires_grad=True` by default. So *all parameters that have `.requires_grad=True` should be optimized*. Next, we make a list of such parameters and input this list to the Adam algorithm constructor.

# %%
# Gather the parameters to be optimized/updated in this run. If we are finetuning we will be updating all parameters. However, if we are 
# doing feature extract method, we will only update the parameters that we have just initialized, i.e. the parameters with requires_grad is True.

params_to_update = []
for name, param in model.named_parameters():
    if param.requires_grad == True:
        params_to_update.append(param)


# Now give our optimiser the list of all the parameters that need to be optimized
optimizer_ft = optim.Adam(params_to_update, lr=0.001)

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 4**: Train the model with feature extraction for 15 epochs. This is, you must freeze all parameters except the last fully connected layer. Plot the train/val losses and accuracies.
#
# Do not overwrite the previous best model, losses and accuracies, keep the new ones in separate variables.
#
# </span>

# %%
# Send the model to GPU
model2= initialize_model(2,False)
model2 = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 15

optimizer_ft = optim.Adam(model2.parameters(), lr=0.001)

# Train and evaluate
model2, hist2, losses2 = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/14
# ----------
# train Loss: 1.1123 Acc: 0.5574
# val Loss: 7.6596 Acc: 0.5882
#
# Epoch 1/14
# ----------
# train Loss: 0.7023 Acc: 0.5820
# val Loss: 0.7854 Acc: 0.6797
#
# Epoch 2/14
# ----------
# train Loss: 0.6557 Acc: 0.5656
# val Loss: 1.0506 Acc: 0.6601
#
# Epoch 3/14
# ----------
# train Loss: 0.6785 Acc: 0.5861
# val Loss: 0.6507 Acc: 0.6732
#
# Epoch 4/14
# ----------
# train Loss: 0.6977 Acc: 0.6148
# val Loss: 0.6024 Acc: 0.6601
#
# Epoch 5/14
# ----------
# train Loss: 0.6432 Acc: 0.6189
# val Loss: 0.5570 Acc: 0.6928
#
# Epoch 6/14
# ----------
# train Loss: 0.6233 Acc: 0.6434
# val Loss: 0.8264 Acc: 0.6732
#
# Epoch 7/14
# ----------
# train Loss: 0.6599 Acc: 0.6189
# val Loss: 0.9970 Acc: 0.6471
#
# Epoch 8/14
# ----------
# train Loss: 0.5943 Acc: 0.6557
# val Loss: 0.5393 Acc: 0.6471
#
# Epoch 9/14
# ----------
# train Loss: 0.6426 Acc: 0.6885
# val Loss: 0.6669 Acc: 0.7059
#
# Epoch 10/14
# ----------
# train Loss: 0.5774 Acc: 0.7254
# val Loss: 0.8423 Acc: 0.6471
#
# Epoch 11/14
# ----------
# train Loss: 0.6018 Acc: 0.7090
# val Loss: 0.7608 Acc: 0.6275
#
# Epoch 12/14
# ----------
# train Loss: 0.6313 Acc: 0.6434
# val Loss: 0.8294 Acc: 0.6732
#
# Epoch 13/14
# ----------
# train Loss: 0.5679 Acc: 0.7049
# val Loss: 0.7017 Acc: 0.6078
#
# Epoch 14/14
# ----------
# train Loss: 0.5586 Acc: 0.7295
# val Loss: 1.1820 Acc: 0.5490
#
# Training complete in 1m 4s
# Best val Acc: 0.705882

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses2["train"], label="training loss")
ax1.plot(losses2["val"], label="validation loss")
ax1.legend()

ax2.plot(hist2["train"],label="training accuracy")
ax2.plot(hist2["val"],label="val accuracy")
ax2.legend()

plt.show()

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 5**: Now train the model finetuning all the parameters for 15 epochs. Plot the train/val losses and accuracies.
#
# Do not overwrite the previous best model, losses and accuracies, keep the new ones in separate variables.
#
# </span>

# %%
# Send the model to GPU
model3= initialize_model(2,True)
model3 = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 15

optimizer_ft = optim.Adam(model2.parameters(), lr=0.001)

# Train and evaluate
model3, hist3, losses3 = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/14
# ----------
# train Loss: 0.7129 Acc: 0.6066
# val Loss: 2.4233 Acc: 0.5882
#
# Epoch 1/14
# ----------
# train Loss: 0.6741 Acc: 0.5533
# val Loss: 1.5850 Acc: 0.5621
#
# Epoch 2/14
# ----------
# train Loss: 0.6375 Acc: 0.6189
# val Loss: 1.1133 Acc: 0.6275
#
# Epoch 3/14
# ----------
# train Loss: 0.6550 Acc: 0.6148
# val Loss: 0.6708 Acc: 0.5817
#
# Epoch 4/14
# ----------
# train Loss: 0.6823 Acc: 0.5861
# val Loss: 0.7523 Acc: 0.5948
#
# Epoch 5/14
# ----------
# train Loss: 0.7099 Acc: 0.5779
# val Loss: 0.8731 Acc: 0.6078
#
# Epoch 6/14
# ----------
# train Loss: 0.6432 Acc: 0.6557
# val Loss: 1.6627 Acc: 0.5686
#
# Epoch 7/14
# ----------
# train Loss: 0.5864 Acc: 0.7049
# val Loss: 1.6344 Acc: 0.6013
#
# Epoch 8/14
# ----------
# train Loss: 0.6840 Acc: 0.6393
# val Loss: 0.8299 Acc: 0.5686
#
# Epoch 9/14
# ----------
# train Loss: 0.6884 Acc: 0.5943
# val Loss: 0.8753 Acc: 0.6275
#
# Epoch 10/14
# ----------
# train Loss: 0.6250 Acc: 0.6926
# val Loss: 0.6801 Acc: 0.6863
#
# Epoch 11/14
# ----------
# train Loss: 0.6614 Acc: 0.5902
# val Loss: 0.8947 Acc: 0.6601
#
# Epoch 12/14
# ----------
# train Loss: 0.6139 Acc: 0.6844
# val Loss: 0.5655 Acc: 0.7778
#
# Epoch 13/14
# ----------
# train Loss: 0.6644 Acc: 0.6025
# val Loss: 0.6537 Acc: 0.6863
#
# Epoch 14/14
# ----------
# train Loss: 0.5670 Acc: 0.7008
# val Loss: 0.7219 Acc: 0.6601
#
# Training complete in 1m 4s
# Best val Acc: 0.777778

# %%
# plot the losses and accuracies
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

ax1.plot(losses3["train"], label="training loss")
ax1.plot(losses3["val"], label="validation loss")
ax1.legend()

ax2.plot(hist3["train"],label="training accuracy")
ax2.plot(hist3["val"],label="val accuracy")
ax2.legend()

plt.show()

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 6**: Plot the  train/val losses and accuracies of all three approaches: training from scratch, finetunning, and festure extraction. To make easier visualization and comparison, use four `plt.subplots`: one for training loss, one for val loss, one for training accuracy, and one for val accuracy.
#
# Make the plot self-explanatory: use legends and titles for each subplot, and a main title for the whole figure.
#
# </span>

# %%
import matplotlib.pyplot as plt

# create a figure with four subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# plot the training loss for all three approaches
axs[0, 0].plot(losses["train"], label='Training from scratch')
axs[0, 0].plot(losses2["train"], label='Fine-tuning')
axs[0, 0].plot(losses3["train"], label='Feature extraction')
axs[0, 0].set_title('Training Loss')
axs[0, 0].set_xlabel('Epoch')
axs[0, 0].set_ylabel('Loss')
axs[0, 0].legend()

# plot the validation loss for all three approaches
axs[0, 1].plot(losses["val"], label='Training from scratch')
axs[0, 1].plot(losses2["val"], label='Fine-tuning')
axs[0, 1].plot(losses3["val"], label='Feature extraction')
axs[0, 1].set_title('Validation Loss')
axs[0, 1].set_xlabel('Epoch')
axs[0, 1].set_ylabel('Loss')
axs[0, 1].legend()

# plot the training accuracy for all three approaches
axs[1, 0].plot(hist["train"], label='Training from scratch')
axs[1, 0].plot(hist2["train"], label='Fine-tuning')
axs[1, 0].plot(hist3["train"], label='Feature extraction')
axs[1, 0].set_title('Training Accuracy')
axs[1, 0].set_xlabel('Epoch')
axs[1, 0].set_ylabel('Accuracy')
axs[1, 0].legend()

# plot the validation accuracy for all three approaches
axs[1, 1].plot(hist["val"], label='Training from scratch')
axs[1, 1].plot(hist2["val"], label='Fine-tuning')
axs[1, 1].plot(hist3["val"], label='Feature extraction')
axs[1, 1].set_title('Validation Accuracy')
axs[1, 1].set_xlabel('Epoch')
axs[1, 1].set_ylabel('Accuracy')
axs[1, 1].legend()

# add a main title for the whole figure
fig.suptitle('Comparison of Training Approaches')

# display the plot
plt.show()

# %%
#In order to run exercice 7 properly
del data
del sample_data

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 7**: Train the ResNet-18 model for a different dataset (MIT Scenes) using the three training strategies: from scratch (do not load pre-trained weights), finetunning, and feature extraction. Train the model **for 40 epochs** - each training process should take approx. 10 minutes on colab.
#
# The URL of the dataset is the following (you also have the file on Campus Virtual):
#
# http://wwwo.cvc.uab.es/people/dimos/downloads/MIT_scenes.zip
#
# The dataset contains scene images of **8 classes**: coast, forest, highway, inside_city, mountain, open_country, street, and tallbuilding. The number of training images per class varies between 187 and 295.
#
# Train the three models and plot the  train/val losses and accuracies of all of them. Again, to make easier visualization and comparison, use four `plt.subplots`: one for training loss, one for val loss, one for training accuracy, and one for val accuracy.
#
# </span>

# %% [markdown]
# ####Prepare the dataset and train function

# %%
# download the dataset
url = 'http://wwwo.cvc.uab.es/people/dimos/downloads/MIT_scenes.zip'
datasets.utils.download_and_extract_archive(url, './data')

data_dir = "./data/MIT_scenes/"

# ResNet input size
input_size = (224,224)

# Just normalization
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(input_size),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Resize(input_size),
        transforms.CenterCrop(input_size),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

print("Initializing Datasets and Dataloaders...")


# Batch size for training (change depending on how much memory you have)
batch_size = 8

# Create training and validation datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transforms[x]) for x in ['train', 'val']}
# Create training and validation dataloaders
dataloaders_dict = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'val']}

print("Done")
# Out:
# Using downloaded and verified file: ./data/MIT_scenes.zip
# Extracting ./data/MIT_scenes.zip to ./data
# Initializing Datasets and Dataloaders...
# Done

# %%
import matplotlib.image as mpimg

# show some images
plt.figure(figsize=(16, 6))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    idx = np.random.randint(0,len(image_datasets['train'].samples))
    image = mpimg.imread(image_datasets['train'].samples[idx][0])
    plt.imshow(image)
    plt.axis('off');

# %%
def train_model(model, dataloaders, criterion, optimizer, num_epochs=25):
    since = time.time()

    acc_history = {"train": [], "val": []}
    losses = {"train": [], "val": []}

    # we will keep a copy of the best weights so far according to validation accuracy
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    # Get model outputs and calculate loss
                    outputs = model(inputs)
                    loss = criterion(outputs, labels)
                    losses[phase].append(loss.item())

                    _, preds = torch.max(outputs, 1)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data).cpu().numpy()

            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            
            acc_history[phase].append(epoch_acc)

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, acc_history, losses

# %% [markdown]
# ####Preparing models

# %%
def initialize_model_from_scratch(num_classes):
    # Resnet18  
    model = models.resnet18()
    model.fc = nn.Linear(512 , num_classes)

    return model, input_size



# Initialize the model
model, input_size = initialize_model_from_scratch(8)

# Print the model we just instantiated
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=8, bias=True)
# )

# %%
# Send the model to GPU
model = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 40

optimizer_ft = optim.Adam(model.parameters(), lr=0.001)

# Train and evaluate
model, hist, losses = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/39
# ----------
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:561: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# train Loss: 2.0046 Acc: 0.2727
# val Loss: 1.4518 Acc: 0.4473
#
# Epoch 1/39
# ----------
# train Loss: 1.5954 Acc: 0.4258
# val Loss: 1.2236 Acc: 0.5489
#
# Epoch 2/39
# ----------
# train Loss: 1.4135 Acc: 0.4700
# val Loss: 1.1323 Acc: 0.5998
#
# Epoch 3/39
# ----------
# train Loss: 1.2845 Acc: 0.5369
# val Loss: 0.9564 Acc: 0.6530
#
# Epoch 4/39
# ----------
# train Loss: 1.2078 Acc: 0.5667
# val Loss: 0.8313 Acc: 0.7138
#
# Epoch 5/39
# ----------
# train Loss: 1.1346 Acc: 0.6018
# val Loss: 0.9044 Acc: 0.6691
#
# Epoch 6/39
# ----------
# train Loss: 1.0855 Acc: 0.6162
# val Loss: 0.7994 Acc: 0.7373
#
# Epoch 7/39
# ----------
# train Loss: 0.9986 Acc: 0.6512
# val Loss: 0.6468 Acc: 0.7732
#
# Epoch 8/39
# ----------
# train Loss: 0.9050 Acc: 0.6816
# val Loss: 0.7868 Acc: 0.7063
#
# Epoch 9/39
# ----------
# train Loss: 0.9438 Acc: 0.6725
# val Loss: 0.6495 Acc: 0.7844
#
# Epoch 10/39
# ----------
# train Loss: 0.9121 Acc: 0.6784
# val Loss: 0.6331 Acc: 0.7968
#
# Epoch 11/39
# ----------
# train Loss: 0.8754 Acc: 0.6954
# val Loss: 0.5889 Acc: 0.8116
#
# Epoch 12/39
# ----------
# train Loss: 0.8938 Acc: 0.6821
# val Loss: 0.5338 Acc: 0.8290
#
# Epoch 13/39
# ----------
# train Loss: 0.8129 Acc: 0.7076
# val Loss: 0.5855 Acc: 0.8104
#
# Epoch 14/39
# ----------
# train Loss: 0.8051 Acc: 0.7236
# val Loss: 0.5501 Acc: 0.8166
#
# Epoch 15/39
# ----------
# train Loss: 0.7999 Acc: 0.7230
# val Loss: 0.5045 Acc: 0.8377
#
# Epoch 16/39
# ----------
# train Loss: 0.7921 Acc: 0.7257
# val Loss: 0.5821 Acc: 0.7968
#
# Epoch 17/39
# ----------
# train Loss: 0.7453 Acc: 0.7384
# val Loss: 0.5042 Acc: 0.8116
#
# Epoch 18/39
# ----------
# train Loss: 0.7380 Acc: 0.7331
# val Loss: 0.5261 Acc: 0.8154
#
# Epoch 19/39
# ----------
# train Loss: 0.7146 Acc: 0.7512
# val Loss: 0.5575 Acc: 0.8141
#
# Epoch 20/39
# ----------
# train Loss: 0.7251 Acc: 0.7267
# val Loss: 0.6164 Acc: 0.7695
#
# Epoch 21/39
# ----------
# train Loss: 0.6961 Acc: 0.7613
# val Loss: 0.5701 Acc: 0.7980
#
# Epoch 22/39
# ----------
# train Loss: 0.6700 Acc: 0.7597
# val Loss: 0.4634 Acc: 0.8401
#
# Epoch 23/39
# ----------
# train Loss: 0.6424 Acc: 0.7815
# val Loss: 0.4099 Acc: 0.8575
#
# Epoch 24/39
# ----------
# train Loss: 0.6717 Acc: 0.7693
# val Loss: 0.5010 Acc: 0.8290
#
# Epoch 25/39
# ----------
# train Loss: 0.6316 Acc: 0.7884
# val Loss: 0.4206 Acc: 0.8587
#
# Epoch 26/39
# ----------
# train Loss: 0.6153 Acc: 0.7815
# val Loss: 0.5327 Acc: 0.8240
#
# Epoch 27/39
# ----------
# train Loss: 0.6518 Acc: 0.7725
# val Loss: 0.4598 Acc: 0.8401
#
# Epoch 28/39
# ----------
# train Loss: 0.5981 Acc: 0.7937
# val Loss: 0.4251 Acc: 0.8501
#
# Epoch 29/39
# ----------
# train Loss: 0.5868 Acc: 0.7911
# val Loss: 0.5073 Acc: 0.8327
#
# Epoch 30/39
# ----------
# train Loss: 0.6288 Acc: 0.7772
# val Loss: 0.5497 Acc: 0.8178
#
# Epoch 31/39
# ----------
# train Loss: 0.5942 Acc: 0.7863
# val Loss: 0.4552 Acc: 0.8265
#
# Epoch 32/39
# ----------
# train Loss: 0.5700 Acc: 0.8070
# val Loss: 0.4284 Acc: 0.8439
#
# Epoch 33/39
# ----------
# train Loss: 0.5503 Acc: 0.8028
# val Loss: 0.3533 Acc: 0.8761
#
# Epoch 34/39
# ----------
# train Loss: 0.5124 Acc: 0.8049
# val Loss: 0.4428 Acc: 0.8253
#
# Epoch 35/39
# ----------
# train Loss: 0.5819 Acc: 0.7863
# val Loss: 0.3944 Acc: 0.8637
#
# Epoch 36/39
# ----------
# train Loss: 0.5544 Acc: 0.8118
# val Loss: 0.3839 Acc: 0.8736
#
# Epoch 37/39
# ----------
# train Loss: 0.5189 Acc: 0.8299
# val Loss: 0.3807 Acc: 0.8625
#
# Epoch 38/39
# ----------
# train Loss: 0.4934 Acc: 0.8283
# val Loss: 0.3284 Acc: 0.8848
#
# Epoch 39/39
# ----------
# train Loss: 0.5322 Acc: 0.8150
# val Loss: 0.3986 Acc: 0.8600
#
# Training complete in 10m 39s
# Best val Acc: 0.884758

# %%
def freeze_model(model):
    for param in model.parameters():
        param.requires_grad = False

# %%
# This is a function that we will adapt in various ways during the rest of the notebook, right now, it just creates and returns the model and the input size of images
def initialize_model(num_classes, finetuning = True):
    # Resnet18  
    model = models.resnet18(weights='DEFAULT')

    if (finetuning == False):
      freeze_model(model)


    input_size = 224
    model.fc = nn.Linear(512 , num_classes)
    return model, input_size

# %%
# Send the model to GPU
model2= initialize_model(8,False)
model2 = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 40

optimizer_ft = optim.Adam(model2.parameters(), lr=0.001)

# Train and evaluate
model2, hist2, losses2 = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/39
# ----------
# train Loss: 0.4795 Acc: 0.8256
# val Loss: 0.4100 Acc: 0.8612
#
# Epoch 1/39
# ----------
# train Loss: 0.4446 Acc: 0.8363
# val Loss: 0.4850 Acc: 0.8414
#
# Epoch 2/39
# ----------
# train Loss: 0.4812 Acc: 0.8405
# val Loss: 0.3644 Acc: 0.8748
#
# Epoch 3/39
# ----------
# train Loss: 0.4544 Acc: 0.8373
# val Loss: 0.3812 Acc: 0.8637
#
# Epoch 4/39
# ----------
# train Loss: 0.4798 Acc: 0.8352
# val Loss: 0.3791 Acc: 0.8649
#
# Epoch 5/39
# ----------
# train Loss: 0.4434 Acc: 0.8480
# val Loss: 0.3581 Acc: 0.8637
#
# Epoch 6/39
# ----------
# train Loss: 0.4066 Acc: 0.8581
# val Loss: 0.3471 Acc: 0.8711
#
# Epoch 7/39
# ----------
# train Loss: 0.4343 Acc: 0.8448
# val Loss: 0.3856 Acc: 0.8587
#
# Epoch 8/39
# ----------
# train Loss: 0.4306 Acc: 0.8533
# val Loss: 0.3744 Acc: 0.8600
#
# Epoch 9/39
# ----------
# train Loss: 0.3878 Acc: 0.8676
# val Loss: 0.2893 Acc: 0.8971
#
# Epoch 10/39
# ----------
# train Loss: 0.4238 Acc: 0.8527
# val Loss: 0.4757 Acc: 0.8439
#
# Epoch 11/39
# ----------
# train Loss: 0.4287 Acc: 0.8543
# val Loss: 0.3581 Acc: 0.8748
#
# Epoch 12/39
# ----------
# train Loss: 0.3953 Acc: 0.8650
# val Loss: 0.3922 Acc: 0.8525
#
# Epoch 13/39
# ----------
# train Loss: 0.4174 Acc: 0.8650
# val Loss: 0.2719 Acc: 0.9058
#
# Epoch 14/39
# ----------
# train Loss: 0.4206 Acc: 0.8543
# val Loss: 0.3383 Acc: 0.8773
#
# Epoch 15/39
# ----------
# train Loss: 0.3899 Acc: 0.8602
# val Loss: 0.2924 Acc: 0.9009
#
# Epoch 16/39
# ----------
# train Loss: 0.3944 Acc: 0.8634
# val Loss: 0.3047 Acc: 0.9021
#
# Epoch 17/39
# ----------
# train Loss: 0.3330 Acc: 0.8825
# val Loss: 0.2675 Acc: 0.9083
#
# Epoch 18/39
# ----------
# train Loss: 0.4076 Acc: 0.8586
# val Loss: 0.3295 Acc: 0.8885
#
# Epoch 19/39
# ----------
# train Loss: 0.3772 Acc: 0.8682
# val Loss: 0.3502 Acc: 0.8748
#
# Epoch 20/39
# ----------
# train Loss: 0.3949 Acc: 0.8602
# val Loss: 0.4335 Acc: 0.8451
#
# Epoch 21/39
# ----------
# train Loss: 0.3939 Acc: 0.8655
# val Loss: 0.3594 Acc: 0.8724
#
# Epoch 22/39
# ----------
# train Loss: 0.3415 Acc: 0.8799
# val Loss: 0.3698 Acc: 0.8649
#
# Epoch 23/39
# ----------
# train Loss: 0.3476 Acc: 0.8799
# val Loss: 0.3207 Acc: 0.8885
#
# Epoch 24/39
# ----------
# train Loss: 0.3652 Acc: 0.8698
# val Loss: 0.3082 Acc: 0.8971
#
# Epoch 25/39
# ----------
# train Loss: 0.3585 Acc: 0.8772
# val Loss: 0.3156 Acc: 0.8885
#
# Epoch 26/39
# ----------
# train Loss: 0.3773 Acc: 0.8698
# val Loss: 0.2617 Acc: 0.9133
#
# Epoch 27/39
# ----------
# train Loss: 0.3404 Acc: 0.8836
# val Loss: 0.3596 Acc: 0.8798
#
# Epoch 28/39
# ----------
# train Loss: 0.3446 Acc: 0.8788
# val Loss: 0.2725 Acc: 0.9021
#
# Epoch 29/39
# ----------
# train Loss: 0.3571 Acc: 0.8799
# val Loss: 0.2903 Acc: 0.9058
#
# Epoch 30/39
# ----------
# train Loss: 0.3328 Acc: 0.8724
# val Loss: 0.3249 Acc: 0.8996
#
# Epoch 31/39
# ----------
# train Loss: 0.3399 Acc: 0.8814
# val Loss: 0.3704 Acc: 0.8724
#
# Epoch 32/39
# ----------
# train Loss: 0.3302 Acc: 0.8814
# val Loss: 0.2186 Acc: 0.9343
#
# Epoch 33/39
# ----------
# train Loss: 0.2936 Acc: 0.9038
# val Loss: 0.2929 Acc: 0.8947
#
# Epoch 34/39
# ----------
# train Loss: 0.3300 Acc: 0.8900
# val Loss: 0.2770 Acc: 0.9095
#
# Epoch 35/39
# ----------
# train Loss: 0.3119 Acc: 0.8921
# val Loss: 0.2618 Acc: 0.9170
#
# Epoch 36/39
# ----------
# train Loss: 0.3329 Acc: 0.8873
# val Loss: 0.2994 Acc: 0.8984
#
# Epoch 37/39
# ----------
# train Loss: 0.3338 Acc: 0.8830
# val Loss: 0.2939 Acc: 0.9021
#
# Epoch 38/39
# ----------
# train Loss: 0.3209 Acc: 0.8862
# val Loss: 0.2699 Acc: 0.9033
#
# Epoch 39/39
# ----------
# train Loss: 0.2978 Acc: 0.9001
# val Loss: 0.3461 Acc: 0.8798
#
# Training complete in 9m 60s
# Best val Acc: 0.934325

# %%
# Send the model to GPU
model3= initialize_model(8,True)
model3 = model.to(device)

# Setup the loss fxn
criterion = nn.CrossEntropyLoss()

# Number of epochs to train for 
num_epochs = 40

optimizer_ft = optim.Adam(model2.parameters(), lr=0.001)

# Train and evaluate
model3, hist3, losses3 = train_model(model, dataloaders_dict, criterion, optimizer_ft, num_epochs=num_epochs)
# Out:
# Epoch 0/39
# ----------
# train Loss: 0.3402 Acc: 0.8804
# val Loss: 0.3529 Acc: 0.8711
#
# Epoch 1/39
# ----------
# train Loss: 0.3528 Acc: 0.8830
# val Loss: 0.2526 Acc: 0.9058
#
# Epoch 2/39
# ----------
# train Loss: 0.3294 Acc: 0.8878
# val Loss: 0.2880 Acc: 0.9083
#
# Epoch 3/39
# ----------
# train Loss: 0.3243 Acc: 0.8862
# val Loss: 0.2688 Acc: 0.9021
#
# Epoch 4/39
# ----------
# train Loss: 0.3277 Acc: 0.8809
# val Loss: 0.2975 Acc: 0.9033
#
# Epoch 5/39
# ----------
# train Loss: 0.3287 Acc: 0.8910
# val Loss: 0.2675 Acc: 0.9170
#
# Epoch 6/39
# ----------
# train Loss: 0.3221 Acc: 0.8841
# val Loss: 0.3216 Acc: 0.8897
#
# Epoch 7/39
# ----------
# train Loss: 0.2952 Acc: 0.8979
# val Loss: 0.2614 Acc: 0.9157
#
# Epoch 8/39
# ----------
# train Loss: 0.3000 Acc: 0.8947
# val Loss: 0.2643 Acc: 0.9083
#
# Epoch 9/39
# ----------
# train Loss: 0.3194 Acc: 0.8905
# val Loss: 0.3236 Acc: 0.8897
#
# Epoch 10/39
# ----------
# train Loss: 0.3168 Acc: 0.8921
# val Loss: 0.2987 Acc: 0.8910
#
# Epoch 11/39
# ----------
# train Loss: 0.3136 Acc: 0.8894
# val Loss: 0.3366 Acc: 0.8773
#
# Epoch 12/39
# ----------
# train Loss: 0.3182 Acc: 0.8937
# val Loss: 0.2723 Acc: 0.9095
#
# Epoch 13/39
# ----------
# train Loss: 0.3093 Acc: 0.8841
# val Loss: 0.3366 Acc: 0.8761
#
# Epoch 14/39
# ----------
# train Loss: 0.3160 Acc: 0.8889
# val Loss: 0.2837 Acc: 0.8996
#
# Epoch 15/39
# ----------
# train Loss: 0.2999 Acc: 0.9048
# val Loss: 0.3746 Acc: 0.8736
#
# Epoch 16/39
# ----------
# train Loss: 0.3023 Acc: 0.8969
# val Loss: 0.3208 Acc: 0.9058
#
# Epoch 17/39
# ----------
# train Loss: 0.2945 Acc: 0.9001
# val Loss: 0.2863 Acc: 0.9120
#
# Epoch 18/39
# ----------
# train Loss: 0.3145 Acc: 0.8931
# val Loss: 0.4232 Acc: 0.8525
#
# Epoch 19/39
# ----------
# train Loss: 0.2629 Acc: 0.9133
# val Loss: 0.2605 Acc: 0.9071
#
# Epoch 20/39
# ----------
# train Loss: 0.2636 Acc: 0.9048
# val Loss: 0.2662 Acc: 0.9071
#
# Epoch 21/39
# ----------
# train Loss: 0.3029 Acc: 0.8990
# val Loss: 0.2486 Acc: 0.9071
#
# Epoch 22/39
# ----------
# train Loss: 0.2742 Acc: 0.9043
# val Loss: 0.3537 Acc: 0.8649
#
# Epoch 23/39
# ----------
# train Loss: 0.3024 Acc: 0.8985
# val Loss: 0.2246 Acc: 0.9306
#
# Epoch 24/39
# ----------
# train Loss: 0.2860 Acc: 0.9059
# val Loss: 0.2996 Acc: 0.8947
#
# Epoch 25/39
# ----------
# train Loss: 0.2798 Acc: 0.9043
# val Loss: 0.3223 Acc: 0.8922
#
# Epoch 26/39
# ----------
# train Loss: 0.2854 Acc: 0.8963
# val Loss: 0.4023 Acc: 0.8600
#
# Epoch 27/39
# ----------
# train Loss: 0.2905 Acc: 0.9043
# val Loss: 0.2836 Acc: 0.9095
#
# Epoch 28/39
# ----------
# train Loss: 0.2926 Acc: 0.8969
# val Loss: 0.2695 Acc: 0.9009
#
# Epoch 29/39
# ----------
# train Loss: 0.2746 Acc: 0.9027
# val Loss: 0.2708 Acc: 0.9058
#
# Epoch 30/39
# ----------
# train Loss: 0.2834 Acc: 0.9107
# val Loss: 0.2517 Acc: 0.9108
#
# Epoch 31/39
# ----------
# train Loss: 0.2903 Acc: 0.9001
# val Loss: 0.3543 Acc: 0.8724
#
# Epoch 32/39
# ----------
# train Loss: 0.2831 Acc: 0.9091
# val Loss: 0.2733 Acc: 0.9009
#
# Epoch 33/39
# ----------
# train Loss: 0.2437 Acc: 0.9256
# val Loss: 0.2661 Acc: 0.9058
#
# Epoch 34/39
# ----------
# train Loss: 0.2644 Acc: 0.9054
# val Loss: 0.2409 Acc: 0.9170
#
# Epoch 35/39
# ----------
# train Loss: 0.2783 Acc: 0.9091
# val Loss: 0.3789 Acc: 0.8724
#
# Epoch 36/39
# ----------
# train Loss: 0.2488 Acc: 0.9197
# val Loss: 0.2953 Acc: 0.9058
#
# Epoch 37/39
# ----------
# train Loss: 0.2668 Acc: 0.9144
# val Loss: 0.3199 Acc: 0.8922
#
# Epoch 38/39
# ----------
# train Loss: 0.2644 Acc: 0.9112
# val Loss: 0.3463 Acc: 0.8897
#
# Epoch 39/39
# ----------
# train Loss: 0.2747 Acc: 0.9070
# val Loss: 0.2577 Acc: 0.9071
#
# Training complete in 10m 10s
# Best val Acc: 0.930607

# %% [markdown]
# ####Results and plot

# %%
import matplotlib.pyplot as plt

# create a figure with four subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# plot the training loss for all three approaches
axs[0, 0].plot(losses["train"], label='Training from scratch')
axs[0, 0].plot(losses2["train"], label='Fine-tuning')
axs[0, 0].plot(losses3["train"], label='Feature extraction')
axs[0, 0].set_title('Training Loss')
axs[0, 0].set_xlabel('Epoch')
axs[0, 0].set_ylabel('Loss')
axs[0, 0].legend()

# plot the validation loss for all three approaches
axs[0, 1].plot(losses["val"], label='Training from scratch')
axs[0, 1].plot(losses2["val"], label='Fine-tuning')
axs[0, 1].plot(losses3["val"], label='Feature extraction')
axs[0, 1].set_title('Validation Loss')
axs[0, 1].set_xlabel('Epoch')
axs[0, 1].set_ylabel('Loss')
axs[0, 1].legend()

# plot the training accuracy for all three approaches
axs[1, 0].plot(hist["train"], label='Training from scratch')
axs[1, 0].plot(hist2["train"], label='Fine-tuning')
axs[1, 0].plot(hist3["train"], label='Feature extraction')
axs[1, 0].set_title('Training Accuracy')
axs[1, 0].set_xlabel('Epoch')
axs[1, 0].set_ylabel('Accuracy')
axs[1, 0].legend()

# plot the validation accuracy for all three approaches
axs[1, 1].plot(hist["val"], label='Training from scratch')
axs[1, 1].plot(hist2["val"], label='Fine-tuning')
axs[1, 1].plot(hist3["val"], label='Feature extraction')
axs[1, 1].set_title('Validation Accuracy')
axs[1, 1].set_xlabel('Epoch')
axs[1, 1].set_ylabel('Accuracy')
axs[1, 1].legend()

# add a main title for the whole figure
fig.suptitle('Comparison of Training Approaches')

# display the plot
plt.show()

# %% [markdown]
# ###Exercice 7.2

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 7**: Visualize some of the images along with the classification results of your best model.
#
# *Hints: (1) The images that the dataloader gives you are already normalised, you need to "de-normalise" them if you want to see the true colours. (2) The order of dimensions of PyTorch is C, H, W, if you want to plot images you need your arrays ordered as H, W, C.*
#
# </span>

# %%
def denormalize(img):
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    return (img * std + mean)

# %%
dataiter = iter(dataloaders_dict['val'])
images, labels = next(dataiter)

# %%
images = images.to(device)
labels = labels.to(device)

# %%
outputs = model2(images)
_, predicted = torch.max(outputs, 1)

# %%
fig = plt.figure(figsize=(10, 10))
for i in range(8):
    ax = plt.subplot(4, 2, i + 1)
    img = images[i].cpu().numpy().transpose((1, 2, 0))
    img = denormalize(img)
    plt.imshow(img)
    ax.set_title(f"Predicted: {image_datasets['val'].classes[predicted[i]]}")
    ax.axis('off')

# show the plot
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
